# %%
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps xformers trl peft accelerate bitsandbytes

# %%
# !export CUDA_VISIBLE_DEVICES=2

# %%
# !echo $CUDA_VISIBLE_DEVICES
# Out:
# 0

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2'

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 512 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.
# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
from transformers import BitsAndBytesConfig
quantization_config = BitsAndBytesConfig(load_in_8bit_fp32_cpu_offload=True)
fourbit_models = [
    "unsloth/mistral-7b-v0.3-bnb-4bit",      # New Mistral v3 2x faster!
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/llama-3-8b-bnb-4bit",           # Llama-3 15 trillion tokens model 2x faster!
    "unsloth/llama-3-8b-Instruct-bnb-4bit",
    "unsloth/llama-3-70b-bnb-4bit",
    "unsloth/Phi-3-mini-4k-instruct",        # Phi-3 2x faster!
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/mistral-7b-bnb-4bit",
    "unsloth/gemma-7b-bnb-4bit",             # Gemma 2.2x faster!
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/llama-3-8b",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    device_map="cuda"

    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# loading configuration file config.json from cache at /home/fansa/.cache/huggingface/hub/models--unsloth--llama-3-8b-bnb-4bit/snapshots/90bd376f78b5ba9ad646082570a99a33801c99ef/config.json
# Model config LlamaConfig {
#   "_name_or_path": "unsloth/llama-3-8b-bnb-4bit",
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.41.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# loading configuration file config.json from cache at /home/fansa/.cache/huggingface/hub/models--unsloth--llama-3-8b-bnb-4bit/snapshots/90bd376f78b5ba9ad646082570a99a33801c99ef/config.json
# Model config LlamaConfig {
#   "_name_or_path": "unsloth/llama-3-8b-bnb-4bit",
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.41.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
# ==((====))==  Unsloth: Fast Llama patching release 2024.5
#    \\   /|    GPU: NVIDIA GeForce RTX 3090. Max memory: 23.691 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.3.1. CUDA = 8.6. CUDA Toolkit = 11.8.
# \        /    Bfloat16 = TRUE. Xformers = 0.0.26.post1. FA = False.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# loading configuration file config.json from cache at /home/fansa/.cache/huggingface/hub/models--unsloth--llama-3-8b-bnb-4bit/snapshots/90bd376f78b5ba9ad646082570a99a33801c99ef/config.json
# Model config LlamaConfig {
#   "_name_or_path": "unsloth/llama-3-8b-bnb-4bit",
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.41.2",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# loading weights file model.safetensors from cache at /home/fansa/.cache/huggingface/hub/models--unsloth--llama-3-8b-bnb-4bit/snapshots/90bd376f78b5ba9ad646082570a99a33801c99ef/model.safetensors
# Instantiating LlamaForCausalLM model under default dtype torch.bfloat16.
# Generate config GenerationConfig {
#   "bos_token_id": 128000,
#   "eos_token_id": 128001
# }
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[40], line 21
#       8 quantization_config = BitsAndBytesConfig(load_in_8bit_fp32_cpu_offload=True)
#       9 fourbit_models = [
#      10     "unsloth/mistral-7b-v0.3-bnb-4bit",      # New Mistral v3 2x faster!
#      11     "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
#    (...)
#      18     "unsloth/gemma-7b-bnb-4bit",             # Gemma 2.2x faster!
#      19 ] # More models at https://huggingface.co/unsloth
# ---> 21 model, tokenizer = FastLanguageModel.from_pretrained(
#      22     model_name = "unsloth/llama-3-8b",
#      23     max_seq_length = max_seq_length,
#      24     dtype = dtype,
#      25     load_in_4bit = load_in_4bit,
#      26     device_map="cuda"
#      27
#      28     # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
#      29 )
#
# File ~/anaconda3/envs/NLP/lib/python3.9/site-packages/unsloth/models/loader.py:142, in FastLanguageModel.from_pretrained(model_name, max_seq_length, dtype, load_in_4bit, token, device_map, rope_scaling, fix_tokenizer, trust_remote_code, use_gradient_checkpointing, resize_model_vocab, *args, **kwargs)
#     139     tokenizer_name = None
#     140 pass
# --> 142 model, tokenizer = dispatch_model.from_pretrained(
#     143     model_name     = model_name,
#     144     max_seq_length = max_seq_length,
#     145     dtype          = dtype,
#     146     load_in_4bit   = load_in_4bit,
#     147     token          = token,
#     148     device_map     = device_map,
#     149     rope_scaling   = rope_scaling,
#     150     fix_tokenizer  = fix_tokenizer,
#     151     model_patcher  = dispatch_model,
#     152     tokenizer_name = tokenizer_name,
#     153     trust_remote_code = trust_remote_code,
#     154     *args, **kwargs,
#     155 )
#     157 if resize_model_vocab is not None:
#     158     model.resize_token_embeddings(resize_model_vocab)
#
# File ~/anaconda3/envs/NLP/lib/python3.9/site-packages/unsloth/models/llama.py:1135, in FastLlamaModel.from_pretrained(model_name, max_seq_length, dtype, load_in_4bit, token, device_map, rope_scaling, fix_tokenizer, model_patcher, tokenizer_name, trust_remote_code, **kwargs)
#    1124         model = AutoModelForCausalLM.from_pretrained(
#    1125             model_name,
#    1126             device_map              = device_map,
#    (...)
#    1132             **kwargs,
#    1133         )
#    1134     else:
# -> 1135         raise error
#    1136     pass
#    1137 pass
#
# File ~/anaconda3/envs/NLP/lib/python3.9/site-packages/unsloth/models/llama.py:1106, in FastLlamaModel.from_pretrained(model_name, max_seq_length, dtype, load_in_4bit, token, device_map, rope_scaling, fix_tokenizer, model_patcher, tokenizer_name, trust_remote_code, **kwargs)
#    1104 max_position_embeddings = max(max_seq_length, model_max_seq_length)
#    1105 try:
# -> 1106     model = AutoModelForCausalLM.from_pretrained(
#    1107         model_name,
#    1108         device_map              = device_map,
#    1109         torch_dtype             = dtype,
#    1110         quantization_config     = bnb_config,
#    1111         token                   = token,
#    1112         rope_scaling            = rope_scaling,
#    1113         max_position_embeddings = max_position_embeddings,
#    1114         trust_remote_code       = trust_remote_code,
#    1115         **kwargs,
#    1116     )
#    1117 except Exception as error:
#    1118     if "rope_scaling" in str(error):
#
# File ~/anaconda3/envs/NLP/lib/python3.9/site-packages/transformers/models/auto/auto_factory.py:563, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561 elif type(config) in cls._model_mapping.keys():
#     562     model_class = _get_model_class(config, cls._model_mapping)
# --> 563     return model_class.from_pretrained(
#     564         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     565     )
#     566 raise ValueError(
#     567     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     568     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     569 )
#
# File ~/anaconda3/envs/NLP/lib/python3.9/site-packages/transformers/modeling_utils.py:3754, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3744     if dtype_orig is not None:
#    3745         torch.set_default_dtype(dtype_orig)
#    3747     (
#    3748         model,
#    3749         missing_keys,
#    3750         unexpected_keys,
#    3751         mismatched_keys,
#    3752         offload_index,
#    3753         error_msgs,
# -> 3754     ) = cls._load_pretrained_model(
#    3755         model,
#    3756         state_dict,
#    3757         loaded_state_dict_keys,  # XXX: rename?
#    3758         resolved_archive_file,
#    3759         pretrained_model_name_or_path,
#    3760         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    3761         sharded_metadata=sharded_metadata,
#    3762         _fast_init=_fast_init,
#    3763         low_cpu_mem_usage=low_cpu_mem_usage,
#    3764         device_map=device_map,
#    3765         offload_folder=offload_folder,
#    3766         offload_state_dict=offload_state_dict,
#    3767         dtype=torch_dtype,
#    3768         hf_quantizer=hf_quantizer,
#    3769         keep_in_fp32_modules=keep_in_fp32_modules,
#    3770         gguf_path=gguf_path,
#    3771     )
#    3773 # make sure token embedding weights are still tied if needed
#    3774 model.tie_weights()
#
# File ~/anaconda3/envs/NLP/lib/python3.9/site-packages/transformers/modeling_utils.py:4214, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_modules, gguf_path)
#    4210                 set_module_tensor_to_device(
#    4211                     model_to_load, key, "cpu", torch.empty(*param.size(), dtype=dtype)
#    4212                 )
#    4213     else:
# -> 4214         new_error_msgs, offload_index, state_dict_index = _load_state_dict_into_meta_model(
#    4215             model_to_load,
#    4216             state_dict,
#    4217             loaded_keys,
#    4218             start_prefix,
#    4219             expected_keys,
#    4220             device_map=device_map,
#    4221             offload_folder=offload_folder,
#    4222             offload_index=offload_index,
#    4223             state_dict_folder=state_dict_folder,
#    4224             state_dict_index=state_dict_index,
#    4225             dtype=dtype,
#    4226             hf_quantizer=hf_quantizer,
#    4227             is_safetensors=is_safetensors,
#    4228             keep_in_fp32_modules=keep_in_fp32_modules,
#    4229             unexpected_keys=unexpected_keys,
#    4230         )
#    4231         error_msgs += new_error_msgs
#    4232 else:
#
# File ~/anaconda3/envs/NLP/lib/python3.9/site-packages/transformers/modeling_utils.py:889, in _load_state_dict_into_meta_model(model, state_dict, loaded_state_dict_keys, start_prefix, expected_keys, device_map, offload_folder, offload_index, state_dict_folder, state_dict_index, dtype, hf_quantizer, is_safetensors, keep_in_fp32_modules, unexpected_keys)
#     887     set_module_tensor_to_device(model, param_name, param_device, **set_module_kwargs)
#     888 else:
# --> 889     hf_quantizer.create_quantized_param(model, param, param_name, param_device, state_dict, unexpected_keys)
#     890     # For quantized modules with FSDP/DeepSpeed Stage 3, we need to quantize the parameter on the GPU
#     891     # and then cast it to CPU to avoid excessive memory usage on each GPU
#     892     # in comparison to the sharded model across GPUs.
#     893     if is_fsdp_enabled() or is_deepspeed_zero3_enabled():
#
# File ~/anaconda3/envs/NLP/lib/python3.9/site-packages/transformers/quantizers/quantizer_bnb_4bit.py:201, in Bnb4BitHfQuantizer.create_quantized_param(self, model, param_value, param_name, target_device, state_dict, unexpected_keys)
#     198             if unexpected_keys is not None and k in unexpected_keys:
#     199                 unexpected_keys.remove(k)
# --> 201     new_value = bnb.nn.Params4bit.from_prequantized(
#     202         data=param_value,
#     203         quantized_stats=quantized_stats,
#     204         requires_grad=False,
#     205         device=target_device,
#     206     )
#     207 else:
#     208     new_value = param_value.to("cpu")
#
# File ~/anaconda3/envs/NLP/lib/python3.9/site-packages/bitsandbytes/nn/modules.py:278, in Params4bit.from_prequantized(cls, data, quantized_stats, requires_grad, device, **kwargs)
#     269 @classmethod
#     270 def from_prequantized(
#     271     cls,
#    (...)
#     276     **kwargs,
#     277 ) -> "Params4bit":
# --> 278     self = torch.Tensor._make_subclass(cls, data.to(device))
#     279     self.requires_grad = requires_grad
#     280     self.quant_state = QuantState.from_dict(qs_dict=quantized_stats, device=device)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 20.00 MiB. GPU

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
